# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Set some Pandas options
pd.set_option('max_columns', 4)
pd.set_option('max_rows', 200)

# Default Plotting Size
mpl.rc("figure", figsize=(20, 8))

# Store data in a consistent place
DATA_DIR = '/vagrant/ds/DS_HK_6/data'

nyagg = pd.read_csv(DATA_DIR + '/nyagg.csv')
nyagg.describe()
# Out:
#               Age      Gender  Signed_In         Ctr
# count  387.000000  387.000000        387  387.000000
# mean    54.762274    0.498708          1    0.023383
# std     28.233030    0.500646          0    0.018326
# min      5.000000    0.000000          1    0.005882
# 25%     30.500000    0.000000          1    0.010126
# 50%     55.000000    0.000000          1    0.021209
# 75%     79.000000    1.000000          1    0.030120
# max    107.000000    1.000000          1    0.202381

# %%
nyagg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 387 entries, 0 to 386
# Data columns (total 4 columns):
# Age          387 non-null int64
# Gender       387 non-null int64
# Signed_In    387 non-null int64
# Ctr          387 non-null float64
# dtypes: float64(1), int64(3)
# memory usage: 15.1 KB

# %%
nyagg.head()
# Out:
#    Age  Gender  Signed_In       Ctr
# 0    5       1          1  0.116667
# 1    6       0          1  0.026042
# 2    6       1          1  0.040580
# 3    7       0          1  0.047792
# 4    7       1          1  0.031965

# %%
plt.scatter(nyagg['Age'], nyagg['Gender'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-84b101a2dd55> in <module>()
# ----> 1 plt.scatter(nyagg['Age'])
#
# TypeError: scatter() takes at least 2 arguments (1 given)

# %%
sns.lmplot("Age", "Gender", nyagg)

# %%
sns.distplot(nyagg['Age'])
