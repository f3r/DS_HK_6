# %%
Count the number of Data points.
What does describe() vs. info() tell you about the sample size of “ozone”?
Calculating the Summary Statistics
What’s Panda’s default way of dealing with missing values for its numpy functions like mean, cumsum and std?
How could you deal with the missing values in the ozone dataset?
Which visual ways would be suitable to explore this dataset? Use them.
Explore the relationships in the dataset.

# %%
import numpy as np
import pandas as pd
from random import sample
# %matplotlib inline

# %%
air = pd.read_csv('../data/airquality.csv')

# %%
air.ix[sample(air.index,10)]
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 51           52    NaN      150   6.3    77      6   21
# 41           42    NaN      259  10.9    93      6   11
# 102         103    NaN      137  11.5    86      8   11
# 22           23      4       25   9.7    61      5   23
# 50           51     13      137  10.3    76      6   20
# 1             2     36      118   8.0    72      5    2
# 32           33    NaN      287   9.7    74      6    2
# 48           49     20       37   9.2    65      6   18
# 85           86    108      223   8.0    85      7   25
# 30           31     37      279   7.4    76      5   31

# %%
air.describe()
#basically tells me that the Ozone datapoint was more difficult to collect. Sample size is smaller.
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind        Temp       Month  \
# count  153.000000  116.000000  146.000000  153.000000  153.000000  153.000000
# mean    77.000000   42.129310  185.931507    9.957516   77.882353    6.993464
# std     44.311398   32.987885   90.058422    3.523001    9.465270    1.416522
# min      1.000000    1.000000    7.000000    1.700000   56.000000    5.000000
# 25%     39.000000   18.000000  115.750000    7.400000   72.000000    6.000000
# 50%     77.000000   31.500000  205.000000    9.700000   79.000000    7.000000
# 75%    115.000000   63.250000  258.750000   11.500000   85.000000    8.000000
# max    153.000000  168.000000  334.000000   20.700000   97.000000    9.000000
#
#               Day
# count  153.000000
# mean    15.803922
# std      8.864520
# min      1.000000
# 25%      8.000000
# 50%     16.000000
# 75%     23.000000
# max     31.000000

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 7 columns):
# Unnamed: 0    153 non-null int64
# Ozone         116 non-null float64
# Solar.R       146 non-null float64
# Wind          153 non-null float64
# Temp          153 non-null int64
# Month         153 non-null int64
# Day           153 non-null int64
# dtypes: float64(3), int64(4)
# memory usage: 9.6 KB

# %%
air.mean()
# Out:
# Unnamed: 0     77.000000
# Ozone          42.129310
# Solar.R       185.931507
# Wind            9.957516
# Temp           77.882353
# Month           6.993464
# Day            15.803922
# dtype: float64

# %%
#panda basically ignores the missing data for

# %%
from ggplot import * 
import seaborn as sns

# %%
air.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1     41      190   7.4    67      5    1
# 1           2     36      118   8.0    72      5    2
# 2           3     12      149  12.6    74      5    3
# 3           4     18      313  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5

# %%
air = air.rename(columns = {'Solar.R':'Solar'})

# %%
air.head()
# Out:
#    Unnamed: 0  Ozone  Solar  Wind  Temp  Month  Day
# 0           1     41    190   7.4    67      5    1
# 1           2     36    118   8.0    72      5    2
# 2           3     12    149  12.6    74      5    3
# 3           4     18    313  11.5    62      5    4
# 4           5    NaN    NaN  14.3    56      5    5

# %%
sns.lmplot("Solar", "Temp", air, hue="Month", size=6, aspect=2)

# %%
sns.lmplot("Wind", "Temp", air, hue="Month", size=6, aspect=2)

# %%
ggplot(air, aes(x='Solar')) + geom_density()
# Out:
# <ggplot: (8783996860381)>

# %%
ggplot(air, aes(x='Ozone')) + geom_histogram(binwidth=50, colour="black", fill="blue")
# Out:
# /home/io/.tools/anaconda/lib/python2.7/site-packages/pandas/util/decorators.py:81: FutureWarning: the 'rows' keyword is deprecated, use 'index' instead
#   warnings.warn(msg, FutureWarning)
# <ggplot: (8783994516297)>
