# %%
# %matplotlib inline

# %%
from __future__ import unicode_literals, division

import IPython
import warnings
import requests
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from pylab import *
from IPython.display import HTML
from IPython.display import display as prnt
from statsmodels.formula.api import ols

# Notebook Options
warnings.filterwarnings('ignore')
np.set_printoptions(suppress=True)

# Matplotlib Styles
c = {'axes.labelsize': 17,
'axes.titlesize': 16,
'figure.figsize': [18, 8],
'grid.linewidth': 1.6,
'legend.fontsize': 17,
'lines.linewidth': 2,
'lines.markeredgewidth': 0.0,
'lines.markersize': 11,
'patch.linewidth': 0.5,
'xtick.labelsize': 16,
'xtick.major.pad': 20,
'xtick.major.width': 2,
'xtick.minor.width': 1,
'ytick.labelsize': 16.0,
'ytick.major.pad': 20,
'ytick.major.width': 2,
'ytick.minor.width': 1 }
wide_c = dict(c, **{'figure.figsize':[20,8]})

# %% [markdown]
# #### Utility Functions

# %%
def table(df,replace_match="",replace_str=""):
    return IPython.display.display(HTML(df.to_html().replace('<table border="1" class="dataframe">','<table class="table table-striped table-hover">').replace(replace_match,replace_str)))

# %% [markdown]
# ### Load the Data

# %%
df = pd.read_csv("DSdataset.csv", sep=',')

# %% [markdown]
# ### Inspect the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25447 entries, 0 to 25446
# Data columns (total 46 columns):
# AI                     25447 non-null int64
# Date                   25447 non-null object
# Time                   25447 non-null object
# TapNumber              25447 non-null int64
# SKU                    25183 non-null float64
# Product                25184 non-null object
# Volume                 25447 non-null float64
# Volume Unit            25183 non-null object
# Charge                 25447 non-null float64
# PricePerViolCharged    25447 non-null float64
# PricePerVolume         25447 non-null float64
# HHPricePerVolume       25447 non-null float64
# Currency Unit          25183 non-null object
# CardNumber             25447 non-null int64
# CardType               25183 non-null object
# CardStatus             559 non-null object
# OriginGroup            25189 non-null object
# OriginUnit             25188 non-null object
# SerialNumber           25183 non-null object
# SoftwareVersion        25441 non-null float64
# SystemRole             25441 non-null object
# Mode                   25441 non-null object
# AreaID                 0 non-null float64
# AreaDesc               0 non-null float64
# LineTemp               0 non-null float64
# CoolerTemp             0 non-null float64
# TempScale              0 non-null float64
# FaultTrip              0 non-null float64
# ContainerSize          25447 non-null int64
# ContainerLevel         25447 non-null int64
# Name                   392 non-null object
# Phone                  0 non-null float64
# Email                  0 non-null float64
# DOB                    25447 non-null object
# Gender                 0 non-null float64
# Address                0 non-null float64
# VolumeRemain           25447 non-null float64
# PrePaidRemain          22067 non-null float64
# PrePaidVolRemain       0 non-null float64
# ID                     25447 non-null int64
# mediaID                0 non-null float64
# mediaType              0 non-null float64
# mediaDesc              0 non-null float64
# mediaPoolID            0 non-null float64
# PourScreenID           0 non-null float64
# PourScreenDesc         0 non-null float64
# dtypes: float64(26), int64(6), object(14)

# %%
table(df.head())
# Out:
# <table class="table table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AI</th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>TapNumber</th>
#       <th>SKU</th>
#       <th>Product</th>
#       <th>Volume</th>
#       <th>Charge</th>
#       <th>PricePerViolCharged</th>
#       <th>PricePerVolume</th>
#       <th>HHPricePerVolume</th>
#       <th>CardNumber</th>
#       <th>CardType</th>
#       <th>CardStatus</th>
#       <th>OriginGroup</th>
#       <th>OriginUnit</th>
#       <th>SerialNumber</th>
#       <th>SoftwareVersion</th>
#       <th>SystemRole</th>
#       <th>Mode</th>
#       <th>Name</th>
#       <th>VolumeRemain</th>
#       <th>PrePaidRemain</th>
#       <th>ID</th>
#       <th>Brand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td> 1</td>
#       <td> 07/04/15</td>
#       <td> 2015-04-07 07:01:32</td>
#       <td> 1</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> 4.60</td>
#       <td> 1.47</td>
#       <td> 0.32</td>
#       <td> 0.32</td>
#       <td> 0.32</td>
#       <td> 850</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> 3.17</td>
#       <td> Satellite</td>
#       <td> Sale</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> 1</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td> 2</td>
#       <td> 07/04/15</td>
#       <td> 2015-04-07 07:01:40</td>
#       <td> 1</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> 1.98</td>
#       <td> 0.63</td>
#       <td> 0.32</td>
#       <td> 0.32</td>
#       <td> 0.32</td>
#       <td> 231</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> 3.17</td>
#       <td> Satellite</td>
#       <td> Sale</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> 2</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td> 3</td>
#       <td> 07/04/15</td>
#       <td> 2015-04-07 07:02:17</td>
#       <td> 1</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> 7.14</td>
#       <td> 2.29</td>
#       <td> 0.32</td>
#       <td> 0.32</td>
#       <td> 0.32</td>
#       <td> 850</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> 3.17</td>
#       <td> Satellite</td>
#       <td> Sale</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> 3</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td> 4</td>
#       <td> 07/04/15</td>
#       <td> 2015-04-07 07:02:39</td>
#       <td> 1</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> 5.36</td>
#       <td> 1.71</td>
#       <td> 0.32</td>
#       <td> 0.32</td>
#       <td> 0.32</td>
#       <td> 850</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> 3.17</td>
#       <td> Satellite</td>
#       <td> Sale</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> 4</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td> 5</td>
#       <td> 07/04/15</td>
#       <td> 2015-04-07 11:02:50</td>
#       <td> 1</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> 4.50</td>
#       <td> 1.44</td>
#       <td> 0.32</td>
#       <td> 0.32</td>
#       <td> 0.32</td>
#       <td> 850</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> 3.17</td>
#       <td>    Master</td>
#       <td> Sale</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> 5</td>
#       <td> 0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Drop unusable columns

# %%
df = df.dropna(axis=1,how='all')

# %%
print df['Volume Unit'].unique()
print df['Currency Unit'].unique()
print df['ContainerSize'].unique()
print df['DOB'].unique()
print df['ContainerLevel'].unique()
# Out:
# [nan 'oz' 'Oz.']
# [nan '$']
# [0]
# ['0000-00-00']
# [0]

# %% [markdown]
# We can see that
#
# * volume is measured in oz
# * currency is measured in dollars
# * ContainerSize is a list of 0s
# * DOB only has 0
#
# So we can drop these columns too

# %%
df.drop(['Volume Unit', 'Currency Unit', 'ContainerSize', 'DOB', 'ContainerLevel'],inplace=True,axis=1)

# %% [markdown]
# ### Convert dates to datetime objects

# %%
FullDate = df.Date.map(lambda x: x) + " " + df.Time.map(lambda x: x)

# %%
for x in range(0, len(df['Date'])):
    df['Time'][x] = pd.to_datetime(FullDate[x], dayfirst=True)

# %%
df['Time'].ix[0:5]
# Out:
# 0   2015-04-07 07:01:32
# 1   2015-04-07 07:01:40
# 2   2015-04-07 07:02:17
# 3   2015-04-07 07:02:39
# 4   2015-04-07 11:02:50
# 5   2015-04-07 11:03:18
# Name: Time, dtype: datetime64[ns]

# %%
df['Time'].describe()
# Out:
# count                   25447
# unique                  23642
# top       2015-04-11 14:07:41
# freq                        6
# dtype: object

# %% [markdown]
# The column is not completely datetime64, and so we still need to clean up the non converted rows

# %%
for x in range(0, len(df['Date'])):
    if type(df['Time'][x]) == pd.tslib.Timestamp:
        continue
    else:
        print "Row " + str(x) + " has a timestamp of " + str(df['Time'][x])
# Out:
# Row 2464 has a timestamp of 0000-00-00 00:00:00
# Row 2655 has a timestamp of 0000-00-00 00:00:00
# Row 20451 has a timestamp of 0000-00-00 00:00:00
# Row 20452 has a timestamp of 0000-00-00 00:00:00
# Row 20453 has a timestamp of 0000-00-00 00:00:00

# %%
pd.options.display.max_columns = 25
dfInspect = df[df['Time'] == "0000-00-00 00:00:00"]
table(dfInspect)
# Out:
# <table class="table table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AI</th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>TapNumber</th>
#       <th>SKU</th>
#       <th>Product</th>
#       <th>Volume</th>
#       <th>Charge</th>
#       <th>PricePerViolCharged</th>
#       <th>PricePerVolume</th>
#       <th>HHPricePerVolume</th>
#       <th>CardNumber</th>
#       <th>CardType</th>
#       <th>CardStatus</th>
#       <th>OriginGroup</th>
#       <th>OriginUnit</th>
#       <th>SerialNumber</th>
#       <th>SoftwareVersion</th>
#       <th>SystemRole</th>
#       <th>Mode</th>
#       <th>Name</th>
#       <th>VolumeRemain</th>
#       <th>PrePaidRemain</th>
#       <th>ID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2464 </th>
#       <td>  98</td>
#       <td> 0000-00-00</td>
#       <td> 0000-00-00 00:00:00</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td>               NaN</td>
#       <td> test from reds</td>
#       <td> NaN</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td>  2465</td>
#     </tr>
#     <tr>
#       <th>2655 </th>
#       <td> 289</td>
#       <td> 0000-00-00</td>
#       <td> 0000-00-00 00:00:00</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td>    test from reds</td>
#       <td>            NaN</td>
#       <td> NaN</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td>  2656</td>
#     </tr>
#     <tr>
#       <th>20451</th>
#       <td>  15</td>
#       <td> 0000-00-00</td>
#       <td> 0000-00-00 00:00:00</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td>               NaN</td>
#       <td>            NaN</td>
#       <td> NaN</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> 20457</td>
#     </tr>
#     <tr>
#       <th>20452</th>
#       <td>  16</td>
#       <td> 0000-00-00</td>
#       <td> 0000-00-00 00:00:00</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> test from indians</td>
#       <td>            NaN</td>
#       <td> NaN</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> 20458</td>
#     </tr>
#     <tr>
#       <th>20453</th>
#       <td>  17</td>
#       <td> 0000-00-00</td>
#       <td> 0000-00-00 00:00:00</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> 0</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td>               NaN</td>
#       <td>            NaN</td>
#       <td> NaN</td>
#       <td>NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> NaN</td>
#       <td> 0</td>
#       <td>NaN</td>
#       <td> 20459</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# From inspecting the above rows I can see that these rows have blank data and so I can remove them

# %%
df = df[df['Time'] != "0000-00-00 00:00:00"]

# %%
for index, row in df.iterrows():
    try: 
        if type(df['Time'][x]) == pd.tslib.Timestamp:
            continue
        else:
            print "Row " + str(x) + " has a timestamp of " + str(df['Time'][x])
    except:
        pass

# %% [markdown]
# ### Convert product categories into numeric data

# %% [markdown]
# Give each product a brand number

# %%
products = sorted(df['Product'].unique())
for x in range(0, len(products)):
    print str(x) + " is " + str(products[x])
# Out:
# 0 is nan
# 1 is BLACK BOX PLUMBERS CRACK
# 2 is BREW KETTLE 4CS
# 3 is BUCKEYE BREWING IPA
# 4 is BUTCHER & BREWER KOLSCH
# 5 is Blue Point Toasted Lager
# 6 is Bud Light
# 7 is Budweiser
# 8 is CROOKED RIVER SETTLERS ALE
# 9 is FAT HEAD`S HEAD HUNTER
# 10 is GREAT LAKES RALLY DRUM
# 11 is Goose Island 312
# 12 is Goose Island IPA
# 13 is Heineken
# 14 is MARKET GARDEN CITRAMAX
# 15 is Michelob Golden
# 16 is Nordeast Grain Belt
# 17 is PLATFORM PALESNER
# 18 is PORTSIDE 216
# 19 is Shock Top
# 20 is Stella Artois
# 21 is Summit EPA
# 22 is Sweetwater 420
# 23 is Sweetwater IPA
# 24 is TD LABRADOR LAGER
# 25 is WILLOUGHBY PEANUT BUTTER CUP

# %%
df_product = pd.get_dummies(df.Product)

# %%
len(df_product.columns)
# Out:
# 25

# %%
brands = list(xrange(1,26))
df_product.columns = brands

# %%
for x in range(0, len(df_product)):
    for y in range(0, len(df_product.columns)):
        if df_product.iloc[x, y] == 1:
            df_product.iloc[x, y] = y+1

# %%
df["Brand"] = df_product.sum(axis=1)

# %%
from random import sample
table(df[['Product', 'Brand']].ix[sample(df.index,5)])
# Out:
# <table class="table table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Product</th>
#       <th>Brand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2307 </th>
#       <td>        Shock Top</td>
#       <td> 19</td>
#     </tr>
#     <tr>
#       <th>18457</th>
#       <td>   Sweetwater IPA</td>
#       <td> 23</td>
#     </tr>
#     <tr>
#       <th>13739</th>
#       <td>        Budweiser</td>
#       <td>  7</td>
#     </tr>
#     <tr>
#       <th>17903</th>
#       <td>        Bud Light</td>
#       <td>  6</td>
#     </tr>
#     <tr>
#       <th>5160 </th>
#       <td> Goose Island IPA</td>
#       <td> 12</td>
#     </tr>
#   </tbody>
# </table>

# %%
y = 0
for x in range(0, len(df.Brand)):
    try:
        if df.Brand[x] == 0:
            y += 1
        else:
            continue
    except:
        pass
print "There are " + str(y) + " instances of the Brand being undefined"
# Out:
# There are 258 instances of the Brand being undefined

# %% [markdown]
# # EDA

# %% [markdown]
# ### Univariate

# %%
table(df.describe())
# Out:
# <table class="table table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AI</th>
#       <th>TapNumber</th>
#       <th>SKU</th>
#       <th>Volume</th>
#       <th>Charge</th>
#       <th>PricePerViolCharged</th>
#       <th>PricePerVolume</th>
#       <th>HHPricePerVolume</th>
#       <th>CardNumber</th>
#       <th>SoftwareVersion</th>
#       <th>VolumeRemain</th>
#       <th>PrePaidRemain</th>
#       <th>ID</th>
#       <th>Brand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td> 25442.000000</td>
#       <td> 25442.000000</td>
#       <td> 25183.000000</td>
#       <td> 25442.000000</td>
#       <td> 25442.000000</td>
#       <td> 25442.000000</td>
#       <td> 25442.000000</td>
#       <td> 25442.000000</td>
#       <td> 25442.000000</td>
#       <td> 25441.000000</td>
#       <td> 25442.000000</td>
#       <td> 22067.000000</td>
#       <td> 25442.000000</td>
#       <td> 25442.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>  5600.452166</td>
#       <td>     1.427875</td>
#       <td> 10001.552476</td>
#       <td>    14.911554</td>
#       <td>     6.177599</td>
#       <td>     0.428539</td>
#       <td>     0.428539</td>
#       <td>     0.331853</td>
#       <td> 50875.553534</td>
#       <td>     3.156578</td>
#       <td>    22.993996</td>
#       <td>     7.764131</td>
#       <td> 12727.098616</td>
#       <td>     8.730682</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>  4917.908566</td>
#       <td>     0.494860</td>
#       <td>     1.021343</td>
#       <td>     6.529932</td>
#       <td>     2.807547</td>
#       <td>     0.067309</td>
#       <td>     0.067309</td>
#       <td>     0.055416</td>
#       <td> 11548.782597</td>
#       <td>     0.045849</td>
#       <td>    14.905906</td>
#       <td>     9.637402</td>
#       <td>  7347.544120</td>
#       <td>     5.365991</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>     1.000000</td>
#       <td>     0.000000</td>
#       <td> 10001.000000</td>
#       <td>     0.000000</td>
#       <td>     0.000000</td>
#       <td>     0.000000</td>
#       <td>     0.000000</td>
#       <td>     0.000000</td>
#       <td>     0.000000</td>
#       <td>     3.000000</td>
#       <td>     0.000000</td>
#       <td>     0.000000</td>
#       <td>     1.000000</td>
#       <td>     0.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>  1339.000000</td>
#       <td>     1.000000</td>
#       <td> 10001.000000</td>
#       <td>    10.240000</td>
#       <td>     4.230000</td>
#       <td>     0.390000</td>
#       <td>     0.390000</td>
#       <td>     0.320000</td>
#       <td> 49770.000000</td>
#       <td>     3.170000</td>
#       <td>    11.950000</td>
#       <td>     1.400000</td>
#       <td>  6366.250000</td>
#       <td>     6.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>  3668.500000</td>
#       <td>     1.000000</td>
#       <td> 10001.000000</td>
#       <td>    15.790000</td>
#       <td>     6.670000</td>
#       <td>     0.390000</td>
#       <td>     0.390000</td>
#       <td>     0.320000</td>
#       <td> 52398.000000</td>
#       <td>     3.170000</td>
#       <td>    25.980000</td>
#       <td>     6.060000</td>
#       <td> 12726.500000</td>
#       <td>     6.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>  9713.750000</td>
#       <td>     2.000000</td>
#       <td> 10002.000000</td>
#       <td>    20.020000</td>
#       <td>     8.190000</td>
#       <td>     0.450000</td>
#       <td>     0.450000</td>
#       <td>     0.320000</td>
#       <td> 54945.000000</td>
#       <td>     3.170000</td>
#       <td>    32.430000</td>
#       <td>    11.540000</td>
#       <td> 19088.750000</td>
#       <td>    10.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td> 16076.000000</td>
#       <td>     2.000000</td>
#       <td> 10006.000000</td>
#       <td>    48.670000</td>
#       <td>    23.330000</td>
#       <td>     0.560000</td>
#       <td>     0.560000</td>
#       <td>     0.560000</td>
#       <td> 65800.000000</td>
#       <td>     3.180000</td>
#       <td>    63.000000</td>
#       <td>    96.040000</td>
#       <td> 25452.000000</td>
#       <td>    25.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.hist(figsize=(18,12))
plt.show()

# %% [markdown]
# ### Reducing data to look at specific and relevant attributes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25442 entries, 0 to 25446
# Data columns (total 25 columns):
# AI                     25442 non-null int64
# Date                   25442 non-null object
# Time                   25442 non-null object
# TapNumber              25442 non-null int64
# SKU                    25183 non-null float64
# Product                25184 non-null object
# Volume                 25442 non-null float64
# Charge                 25442 non-null float64
# PricePerViolCharged    25442 non-null float64
# PricePerVolume         25442 non-null float64
# HHPricePerVolume       25442 non-null float64
# CardNumber             25442 non-null int64
# CardType               25183 non-null object
# CardStatus             559 non-null object
# OriginGroup            25187 non-null object
# OriginUnit             25187 non-null object
# SerialNumber           25183 non-null object
# SoftwareVersion        25441 non-null float64
# SystemRole             25441 non-null object
# Mode                   25441 non-null object
# Name                   392 non-null object
# VolumeRemain           25442 non-null float64
# PrePaidRemain          22067 non-null float64
# ID                     25442 non-null int64
# Brand                  25442 non-null float64
# dtypes: float64(10), int64(4), object(11)

# %%
df1 = df[['Date', 'Time', 'TapNumber', 'Brand', 'Volume', 'Charge', 'PricePerVolume', 'VolumeRemain', 'PrePaidRemain', 'CardNumber', 'CardType', 'OriginGroup', 'OriginUnit', 'Product']]

# %%
f, ax = plt.subplots(figsize=(9, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.corrplot(df1, annot=False, sig_stars=False,
             diag_names=False, cmap=cmap, ax=ax);

# %% [markdown]
# For obvious reasons there is a very strong correlation between the volume of beer poured and the charge for that pour.  There is also a strong relationship between the Brand and the PricePerVolume as beers are chared at a set price.
#
# Interestingly, there is not a strong relationship between the VolumeRemain and the PrePaidRemain.  This is surprising as these should be directly correlated - amount of money left on the card should relate to the volume able to be poured.

# %% [markdown]
# ### Checking for normality

# %% [markdown]
# TO DO

# %% [markdown]
# ### Bivariate

# %%
b, g, r, p = sns.color_palette("muted", 4)

with sns.plotting_context("poster", font_scale=1, rc=c):
    g = sns.PairGrid(df1, hue="Brand")
    g.map_diag(plt.hist)
    g.map_offdiag(plt.scatter)
    g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-6dd5fc29328e> in <module>()
#       3 with sns.plotting_context("poster", font_scale=1, rc=c):
#       4     g = sns.PairGrid(df1, hue="Brand")
# ----> 5     g.map_diag(plt.hist)
#       6     g.map_offdiag(plt.scatter)
#       7     g.add_legend()
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map_diag(self, func, **kwargs)
#     947                 vals = [v.values for g, v in hue_grouped]
#     948                 func(vals, color=self.palette, histtype="barstacked",
# --> 949                      **kwargs)
#     950             else:
#     951                 for k, (label_k, data_k) in enumerate(hue_grouped):
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2888                       histtype=histtype, align=align, orientation=orientation,
#    2889                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2890                       stacked=stacked, **kwargs)
#    2891         draw_if_interactive()
#    2892     finally:
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5634             # this will automatically overwrite bins,
#    5635             # so that each histogram uses the same bins
# -> 5636             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    5637             m = m.astype(float)  # causes problems later if it's an int
#    5638             if mlast is None:
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     174         if (mn > mx):
#     175             raise AttributeError(
# --> 176                 'max must be larger than min in range parameter.')
#     177
#     178     if not iterable(bins):
#
# AttributeError: max must be larger than min in range parameter.

# %% [markdown]
# ### Looking at the Volume of beer poured

# %%
df1['Volume'].describe()
# Out:
# count    25442.000000
# mean        14.911554
# std          6.529932
# min          0.000000
# 25%         10.240000
# 50%         15.790000
# 75%         20.020000
# max         48.670000
# dtype: float64

# %% [markdown]
# There are 16 oz in a pint and we can see that on average users pour just under a pint, at 14.9 oz.
# 25% of pours are greater than 20 oz meaning that these users must have cups that are larger than pints.

# %%
f, axes = plt.subplots(figsize=(17, 5))
sns.distplot(df['Volume'], color="dodgerblue");

# %% [markdown]
# The above histogram is bi-modal, with two distict peaks in volume poured:
#
# * At around the 16oz mark (1 pint)
# * At around the 23oz mark
#
# After speaking with DraftServ I have determined that this is due to different cup sizes being used

# %%
sns.lmplot('Volume', 'Charge', df, hue="TapNumber", size=9, aspect=2);

# %%
sns.lmplot('Volume', 'PricePerVolume', df, color="seagreen", size=5, aspect=2);

# %%
sns.lmplot('Volume', 'PrePaidRemain', df, size=9, aspect=2);

# %% [markdown]
# ### VolumeRemain and PrePaidRemain relationships

# %%
sns.lmplot('VolumeRemain', 'PrePaidRemain', df1, size=9, aspect=2);

# %% [markdown]
# ### Impact of brand

# %% [markdown]
# Every location only stocks a set number of beers.  Firstly let's determine which beers are being stocked where:

# %%
for x in range(0, len(df.OriginGroup.unique())):
    dfOrigin = df.loc[df['OriginGroup'] == df.OriginGroup.unique()[x]]
    print str(df.OriginGroup.unique()[x]) + ":"
    for x in range(0, len(dfOrigin.Product.unique())):
        print "   - " + str(dfOrigin.Product.unique()[x])
# Out:
# nan:
# ab.onpremise:
#    - Goose Island IPA
#    - Bud Light
#    - Michelob Golden
#    - Summit EPA
#    - Nordeast Grain Belt
#    - Shock Top
#    - nan
#    - Budweiser
# philips.arena:
#    - Bud Light
#    - Sweetwater IPA
#    - Heineken
#    - Blue Point Toasted Lager
#    - Sweetwater 420
# testp:
#    - nan
# test1:
#    - nan
# DNC:
#    - Bud Light
#    - GREAT LAKES RALLY DRUM
#    - BUCKEYE BREWING IPA
#    - BREW KETTLE 4CS
#    - FAT HEAD`S HEAD HUNTER
#    - PLATFORM PALESNER
#    - TD LABRADOR LAGER
#    - BUTCHER & BREWER KOLSCH
#    - WILLOUGHBY PEANUT BUTTER CUP
#    - MARKET GARDEN CITRAMAX
#    - BLACK BOX PLUMBERS CRACK
#    - CROOKED RIVER SETTLERS ALE
#    - PORTSIDE 216
# ab.naz:
#    - Bud Light
#    - Budweiser
#    - Stella Artois
#    - Goose Island 312

# %% [markdown]
# As a bit more info on each arena:
#
# * Philips Arena is an indoor sports arena and home of the Atlanta Hawks
# * DNC refers to the Cleveland Indians baseball team at Progressive Field
# * ab.onpremises refers to two baseball stadiums:
#     * the Cincinnati Reds baseball team who play at the Great American Ball Park
#     * the Minnesota Twins who play at Target Field
# * ab.naz refers to...

# %%
for x in range(0, len(df.OriginUnit.unique())):
    dfOrigin = df.loc[df['OriginUnit'] == df.OriginUnit.unique()[x]]
    print str(df.OriginUnit.unique()[x]) + ":"
    for x in range(0, len(dfOrigin.Product.unique())):
        print "   - " + str(dfOrigin.Product.unique()[x])
# Out:
# nan:
# twins01.r:
#    - Goose Island IPA
#    - Bud Light
# twins02.l:
#    - Michelob Golden
#    - Shock Top
# twins03.l:
#    - Summit EPA
#    - Nordeast Grain Belt
# twins03.r:
#    - Summit EPA
#    - Nordeast Grain Belt
# twins02.r:
#    - Michelob Golden
#    - Shock Top
# twins01.l:
#    - Bud Light
#    - Goose Island IPA
# reds10.r:
#    - nan
#    - Goose Island IPA
#    - Bud Light
# reds13.l:
#    - Bud Light
#    - Budweiser
# reds06.r:
#    - Bud Light
# reds20.l:
#    - Bud Light
#    - Budweiser
# reds07.r:
#    - Bud Light
# reds20.r:
#    - Budweiser
#    - Bud Light
# reds06.l:
#    - Bud Light
# reds19.r:
#    - Bud Light
#    - Budweiser
# reds19.l:
#    - Bud Light
#    - Budweiser
# reds12.l:
#    - Bud Light
#    - Budweiser
# reds16.l:
#    - Budweiser
#    - Bud Light
# reds03.r:
#    - Goose Island IPA
#    - Bud Light
# reds03.l:
#    - Bud Light
#    - Goose Island IPA
# reds07.l:
#    - Bud Light
# reds02.l:
#    - Bud Light
# reds17.l:
#    - Bud Light
# reds02.r:
#    - Bud Light
# reds08.l:
#    - Bud Light
# reds10.l:
#    - Goose Island IPA
#    - Bud Light
# reds04.r:
#    - Bud Light
# reds04.l:
#    - Bud Light
# reds09.r:
#    - Bud Light
#    - Goose Island IPA
# reds01.r:
#    - Goose Island IPA
#    - Bud Light
# reds01.l:
#    - Goose Island IPA
#    - Bud Light
# reds13.r:
#    - Budweiser
#    - Bud Light
# reds14.l:
#    - Bud Light
#    - Budweiser
# reds15.l:
#    - Bud Light
# reds16.r:
#    - Budweiser
#    - Bud Light
# reds17.r:
#    - Bud Light
# reds09.l:
#    - Bud Light
#    - Goose Island IPA
# reds11.l:
#    - Budweiser
#    - Bud Light
# reds15.r:
#    - Bud Light
# reds12.r:
#    - Budweiser
#    - Bud Light
# reds05.l:
#    - Bud Light
# reds11.r:
#    - Budweiser
#    - Bud Light
# reds05.r:
#    - Bud Light
# reds14.r:
#    - Bud Light
#    - Budweiser
# reds18.r:
#    - Bud Light
# reds18.l:
#    - Bud Light
# reds08.r:
#    - Bud Light
# philips01.r:
#    - Bud Light
#    - Blue Point Toasted Lager
# philips03.l:
#    - Sweetwater IPA
#    - Sweetwater 420
# philips02.l:
#    - Heineken
# philips02.r:
#    - Heineken
# philips01.l:
#    - Blue Point Toasted Lager
#    - Bud Light
# philips03.r:
#    - Sweetwater IPA
#    - Sweetwater 420
# testp:
#    - nan
# test2:
#    - nan
# Indians02:
#    - Bud Light
#    - FAT HEAD`S HEAD HUNTER
#    - PORTSIDE 216
# Indians01:
#    - Bud Light
#    - BREW KETTLE 4CS
#    - TD LABRADOR LAGER
# Indians04:
#    - Bud Light
#    - MARKET GARDEN CITRAMAX
#    - BLACK BOX PLUMBERS CRACK
# Indians03:
#    - Bud Light
#    - WILLOUGHBY PEANUT BUTTER CUP
#    - CROOKED RIVER SETTLERS ALE
# Indians06:
#    - Bud Light
#    - GREAT LAKES RALLY DRUM
#    - BUCKEYE BREWING IPA
# Indians05:
#    - Bud Light
#    - PLATFORM PALESNER
#    - BUTCHER & BREWER KOLSCH
# united02.r:
#    - Bud Light
#    - Budweiser
# united01.l:
#    - Bud Light
#    - Stella Artois
#    - Goose Island 312
# united01.r:
#    - Bud Light
#    - Goose Island 312
#    - Stella Artois
# united02.l:
#    - Bud Light
#    - Budweiser

# %%
dfBrand = df1[['Brand', 'Volume', 'Charge']]

# %%
sns.pairplot(dfBrand, hue="Brand", size=4);

# %% [markdown]
# ### Inspecting date ranges

# %%
dfDateSort = df.sort(['Date'], ascending=[1])

# %%
dfDateSort['Date'].unique()
# Out:
# array(['01/04/15', '03/04/15', '04/04/15', '05/04/15', '06/04/15',
#        '07/04/15', '08/04/15', '09/04/15', '10/04/15', '11/04/15',
#        '12/04/15', '13/04/15', '14/04/15', '15/04/15', '16/04/15',
#        '17/04/15', '18/04/15', '19/04/15', '20/04/15', '21/04/15',
#        '22/04/15', '24/04/15', '25/04/15', '26/04/15', '28/03/15',
#        '30/03/15', '31/03/15'], dtype=object)

# %%
fig1, ax1 = plt.subplots(figsize=(15,7))
ax1.plot(dfDateSort['Time'], dfDateSort['Volume']);

# %%
dfApr7 = df[df['Date'] == "07/04/15"]

# %%
fig1, ax1 = plt.subplots(figsize=(15,7))
ax1.plot(dfApr7['Time'], dfApr7['Volume']);

# %%
dfApr7 = dfApr7.ix[18454:]

# %%
fig1, ax1 = plt.subplots(figsize=(15,7))
ax1.plot(dfApr7['Time'], dfApr7['Volume']);

# %%
dfApr7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284 entries, 18454 to 18737
# Data columns (total 25 columns):
# AI                     284 non-null int64
# Date                   284 non-null object
# Time                   284 non-null object
# TapNumber              284 non-null int64
# SKU                    284 non-null float64
# Product                284 non-null object
# Volume                 284 non-null float64
# Charge                 284 non-null float64
# PricePerViolCharged    284 non-null float64
# PricePerVolume         284 non-null float64
# HHPricePerVolume       284 non-null float64
# CardNumber             284 non-null int64
# CardType               284 non-null object
# CardStatus             78 non-null object
# OriginGroup            284 non-null object
# OriginUnit             284 non-null object
# SerialNumber           284 non-null object
# SoftwareVersion        284 non-null float64
# SystemRole             284 non-null object
# Mode                   284 non-null object
# Name                   77 non-null object
# VolumeRemain           284 non-null float64
# PrePaidRemain          206 non-null float64
# ID                     284 non-null int64
# Brand                  284 non-null float64
# dtypes: float64(10), int64(4), object(11)

# %%
fig1, ax1 = plt.subplots(figsize=(15,7))
sns.distplot(dfApr7['Volume'], color="dodgerblue");

# %%
dfApr7.CardType.unique()
# Out:
# array(['Pre Paid Currency', 'Staff'], dtype=object)

# %%
dfApr7.CardType.describe()
# Out:
# count                   284
# unique                    2
# top       Pre Paid Currency
# freq                    206
# dtype: object

# %% [markdown]
# ## Analysing user behaviour

# %% [markdown]
# ### Inspecting a specific user

# %% [markdown]
# As a first step in analysing user behaviour we can look at one specific user.

# %%
df1.loc[df1['CardNumber'] == 60233]
# Out:
#           Date                 Time  TapNumber  Brand  Volume  Charge  \
# 1126  15/04/15  2015-04-15 21:56:24          1     19    1.71    0.73
# 1127  15/04/15  2015-04-15 21:56:50          2     16    1.05    0.45
# 1131  15/04/15  2015-04-15 21:57:21          2     15   17.81    6.68
# 1134  15/04/15  2015-04-15 21:57:42          2     15   11.48    4.30
#
#       PricePerVolume  VolumeRemain  PrePaidRemain  CardNumber  \
# 1126            0.43         30.29          14.27       60233
# 1127            0.43         29.24          13.82       60233
# 1131            0.38         11.43           7.14       60233
# 1134            0.38          0.00           2.84       60233
#
#                CardType   OriginGroup OriginUnit              Product
# 1126  Pre Paid Currency  ab.onpremise  twins02.l            Shock Top
# 1127  Pre Paid Currency  ab.onpremise  twins03.l  Nordeast Grain Belt
# 1131  Pre Paid Currency  ab.onpremise  twins02.r      Michelob Golden
# 1134  Pre Paid Currency  ab.onpremise  twins02.r      Michelob Golden

# %% [markdown]
# The above shows us that:
#
# * The user first tried a small amount of beers 19 and 16
# * He/she then opted to pour two pints of beer 15, using up all of the money on that card

# %% [markdown]
# ### Staff cards vs Pre Paid Currency

# %% [markdown]
# There are two types of card: Staff and Pre Paid Currency

# %%
dfStaff = df1.loc[df1['CardType'] == "Staff"]
print "There are " + str(len(dfStaff)) + " staff card entries"
# Out:
# There are 3123 staff card entries

# %%
fig1, ax1 = plt.subplots(figsize=(15,7))
sns.distplot(dfStaff['Volume'], color="seagreen");

# %% [markdown]
# We can see that there are a lot of low volume pours that staff cards make.  This is for demonstration and marketing purposes

# %%
dfPrePaid = df1.loc[df1['CardType'] == "Pre Paid Currency"]
print "There are " + str(len(dfPrePaid)) + " Pre Paid Currency card entries"
# Out:
# There are 22060 Pre Paid Currency card entries

# %%
fig1, ax1 = plt.subplots(figsize=(15,7))
sns.distplot(dfPrePaid['Volume'], color="purple");

# %% [markdown]
# We can see that Pre Paid Currency cards tend to pour larger volume cups more regularly than staff cards

# %%
dfnan = df.loc[df['CardType'] != "Pre Paid Currency"]
dfnan = dfnan.loc[df['CardType'] != "Staff"]
print "There are " + str(len(dfnan)) + " empty card entries"
# Out:
# There are 259 empty card entries

# %% [markdown]
# It is unclear who these card users are and so when running user analysis we will focus on Pre Paid Currency cards

# %% [markdown]
# ### Analysing "pre paid currency" users

# %%
table(dfPrePaid.ix[sample(df.index,5)])
# Out:
# <table class="table table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Time</th>
#       <th>TapNumber</th>
#       <th>Brand</th>
#       <th>Volume</th>
#       <th>Charge</th>
#       <th>PricePerVolume</th>
#       <th>VolumeRemain</th>
#       <th>PrePaidRemain</th>
#       <th>CardNumber</th>
#       <th>CardType</th>
#       <th>OriginGroup</th>
#       <th>OriginUnit</th>
#       <th>Product</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7127 </th>
#       <td> 08/04/15</td>
#       <td> 2015-04-08 19:46:14</td>
#       <td> 1</td>
#       <td>  6</td>
#       <td> 15.17</td>
#       <td>  5.85</td>
#       <td> 0.39</td>
#       <td> 32.83</td>
#       <td>  0.00</td>
#       <td> 51601</td>
#       <td> Pre Paid Currency</td>
#       <td> ab.onpremise</td>
#       <td>   reds03.l</td>
#       <td>        Bud Light</td>
#     </tr>
#     <tr>
#       <th>25139</th>
#       <td> 21/04/15</td>
#       <td> 2015-04-21 22:33:25</td>
#       <td> 1</td>
#       <td> 20</td>
#       <td> 16.95</td>
#       <td>  8.05</td>
#       <td> 0.47</td>
#       <td> 23.05</td>
#       <td> 11.95</td>
#       <td> 45959</td>
#       <td> Pre Paid Currency</td>
#       <td>       ab.naz</td>
#       <td> united01.r</td>
#       <td>    Stella Artois</td>
#     </tr>
#     <tr>
#       <th>5003 </th>
#       <td> 06/04/15</td>
#       <td> 2015-04-06 17:12:35</td>
#       <td> 2</td>
#       <td>  6</td>
#       <td> 31.31</td>
#       <td> 12.07</td>
#       <td> 0.39</td>
#       <td> 16.69</td>
#       <td>  0.00</td>
#       <td> 50280</td>
#       <td> Pre Paid Currency</td>
#       <td> ab.onpremise</td>
#       <td>   reds18.r</td>
#       <td>        Bud Light</td>
#     </tr>
#     <tr>
#       <th>17750</th>
#       <td> 25/04/15</td>
#       <td> 2015-04-25 13:43:17</td>
#       <td> 1</td>
#       <td>  6</td>
#       <td> 13.74</td>
#       <td>  5.29</td>
#       <td> 0.39</td>
#       <td> 16.12</td>
#       <td>  7.72</td>
#       <td> 54934</td>
#       <td> Pre Paid Currency</td>
#       <td> ab.onpremise</td>
#       <td>   reds01.l</td>
#       <td>        Bud Light</td>
#     </tr>
#     <tr>
#       <th>10893</th>
#       <td> 11/04/15</td>
#       <td> 2015-04-11 13:16:12</td>
#       <td> 2</td>
#       <td> 12</td>
#       <td> 20.19</td>
#       <td> 10.94</td>
#       <td> 0.54</td>
#       <td> 27.81</td>
#       <td>  0.73</td>
#       <td> 51962</td>
#       <td> Pre Paid Currency</td>
#       <td> ab.onpremise</td>
#       <td>   reds09.l</td>
#       <td> Goose Island IPA</td>
#     </tr>
#   </tbody>
# </table>

# %%
grouped = dfPrePaid.groupby('Brand').mean()
grouped = grouped.reset_index()
table(grouped)
# Out:
# <table class="table table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Brand</th>
#       <th>TapNumber</th>
#       <th>Volume</th>
#       <th>Charge</th>
#       <th>PricePerVolume</th>
#       <th>VolumeRemain</th>
#       <th>PrePaidRemain</th>
#       <th>CardNumber</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0 </th>
#       <td>  1</td>
#       <td> 1.000000</td>
#       <td> 11.126646</td>
#       <td> 6.230621</td>
#       <td> 0.560000</td>
#       <td> 43.214410</td>
#       <td>  9.368509</td>
#       <td> 59512.285714</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td>  2</td>
#       <td> 1.000000</td>
#       <td> 12.557708</td>
#       <td> 7.032604</td>
#       <td> 0.560000</td>
#       <td> 41.334219</td>
#       <td> 11.952500</td>
#       <td> 58816.343750</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td>  3</td>
#       <td> 1.000000</td>
#       <td> 12.384306</td>
#       <td> 6.935231</td>
#       <td> 0.560000</td>
#       <td> 41.322593</td>
#       <td> 10.830833</td>
#       <td> 59939.699074</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td>  4</td>
#       <td> 1.000000</td>
#       <td> 11.616579</td>
#       <td> 6.504737</td>
#       <td> 0.560000</td>
#       <td> 42.031466</td>
#       <td>  9.555489</td>
#       <td> 60505.684211</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td>  5</td>
#       <td> 2.000000</td>
#       <td> 12.643103</td>
#       <td> 5.694138</td>
#       <td> 0.450460</td>
#       <td> 16.155402</td>
#       <td>  5.251839</td>
#       <td> 40933.770115</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td>  6</td>
#       <td> 1.214647</td>
#       <td> 16.654432</td>
#       <td> 6.397507</td>
#       <td> 0.388002</td>
#       <td> 25.500619</td>
#       <td>  7.534513</td>
#       <td> 51548.207142</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td>  7</td>
#       <td> 2.000000</td>
#       <td> 16.627501</td>
#       <td> 6.427578</td>
#       <td> 0.391351</td>
#       <td> 26.680208</td>
#       <td>  7.148730</td>
#       <td> 52243.487993</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td>  8</td>
#       <td> 1.000000</td>
#       <td> 12.352857</td>
#       <td> 6.917619</td>
#       <td> 0.560000</td>
#       <td> 42.005317</td>
#       <td> 12.076032</td>
#       <td> 61522.103175</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td>  9</td>
#       <td> 1.000000</td>
#       <td> 11.647022</td>
#       <td> 6.522322</td>
#       <td> 0.560000</td>
#       <td> 44.015765</td>
#       <td> 12.245628</td>
#       <td> 59750.653005</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td> 10</td>
#       <td> 2.000000</td>
#       <td> 11.566654</td>
#       <td> 6.477192</td>
#       <td> 0.560000</td>
#       <td> 45.201269</td>
#       <td> 11.232038</td>
#       <td> 62622.730769</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td> 11</td>
#       <td> 2.000000</td>
#       <td> 14.481192</td>
#       <td> 6.878497</td>
#       <td> 0.470000</td>
#       <td> 19.165907</td>
#       <td> 11.568912</td>
#       <td> 46650.626943</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td> 12</td>
#       <td> 1.725921</td>
#       <td> 14.938357</td>
#       <td> 7.645170</td>
#       <td> 0.509851</td>
#       <td> 24.430864</td>
#       <td>  7.198803</td>
#       <td> 54208.786827</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td> 13</td>
#       <td> 1.571906</td>
#       <td> 12.379732</td>
#       <td> 5.592910</td>
#       <td> 0.451605</td>
#       <td> 15.499532</td>
#       <td>  4.800167</td>
#       <td> 41286.538462</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td> 14</td>
#       <td> 2.000000</td>
#       <td> 12.146225</td>
#       <td> 6.801689</td>
#       <td> 0.560000</td>
#       <td> 43.669073</td>
#       <td> 11.961921</td>
#       <td> 60990.476821</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td> 15</td>
#       <td> 2.000000</td>
#       <td> 14.183789</td>
#       <td> 5.318943</td>
#       <td> 0.380000</td>
#       <td> 12.925567</td>
#       <td>  5.152448</td>
#       <td> 59408.095361</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td> 16</td>
#       <td> 2.000000</td>
#       <td> 13.948579</td>
#       <td> 5.928719</td>
#       <td> 0.430000</td>
#       <td> 13.055376</td>
#       <td>  4.298774</td>
#       <td> 59568.768802</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td> 17</td>
#       <td> 2.000000</td>
#       <td> 12.216432</td>
#       <td> 6.840954</td>
#       <td> 0.560000</td>
#       <td> 41.965892</td>
#       <td> 10.605062</td>
#       <td> 57481.912863</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td> 18</td>
#       <td> 2.000000</td>
#       <td> 11.584776</td>
#       <td> 6.487687</td>
#       <td> 0.560000</td>
#       <td> 42.698955</td>
#       <td> 13.082388</td>
#       <td> 61595.679104</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td> 19</td>
#       <td> 1.000000</td>
#       <td> 14.195176</td>
#       <td> 6.033171</td>
#       <td> 0.430000</td>
#       <td> 13.757425</td>
#       <td>  4.349458</td>
#       <td> 59549.758808</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td> 20</td>
#       <td> 1.000000</td>
#       <td> 14.498536</td>
#       <td> 6.886607</td>
#       <td> 0.470000</td>
#       <td> 18.890321</td>
#       <td> 12.551107</td>
#       <td> 47015.857143</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td> 21</td>
#       <td> 1.000000</td>
#       <td> 14.372078</td>
#       <td> 6.108584</td>
#       <td> 0.430000</td>
#       <td> 13.571145</td>
#       <td>  3.942500</td>
#       <td> 59695.286145</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td> 22</td>
#       <td> 1.000000</td>
#       <td> 12.829705</td>
#       <td> 5.773333</td>
#       <td> 0.450000</td>
#       <td> 16.381857</td>
#       <td>  5.735063</td>
#       <td> 39836.379747</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td> 23</td>
#       <td> 2.000000</td>
#       <td> 13.598472</td>
#       <td> 6.125046</td>
#       <td> 0.450370</td>
#       <td> 15.076343</td>
#       <td>  4.964861</td>
#       <td> 39011.287037</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td> 24</td>
#       <td> 2.000000</td>
#       <td> 10.337101</td>
#       <td> 5.788116</td>
#       <td> 0.560000</td>
#       <td> 44.195217</td>
#       <td>  9.746087</td>
#       <td> 60400.391304</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td> 25</td>
#       <td> 2.000000</td>
#       <td> 11.755000</td>
#       <td> 6.582568</td>
#       <td> 0.560000</td>
#       <td> 45.844091</td>
#       <td> 12.131159</td>
#       <td> 60122.622727</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig1, ax1 = plt.subplots(figsize=(15,7))
sns.barplot('Brand', 'Volume', data=grouped);

# %% [markdown]
# #### Sort by users

# %%
dfUserSort = dfPrePaid.sort(['CardNumber'], ascending=[1])

# %% [markdown]
# #### Looking at the relationship between card balance and volume poured

# %%
dfUserSort["BalancePrePour"] = 0.0

for x, row in dfUserSort.iterrows():
    dfUserSort["BalancePrePour"].ix[x] = dfUserSort["PrePaidRemain"].ix[x] + dfUserSort["Charge"].ix[x]

# %%
sns.lmplot('BalancePrePour', 'Volume', dfUserSort, size=9, aspect=2);

# %% [markdown]
# There appears to be some kind of relationship between card balance and the volume poured.

# %%
results = ols('BalancePrePour ~ Volume', dfUserSort).fit()
print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-101-518efa67ef91> in <module>()
# ----> 1 results = ols('BalancePrePour ~ Volume', dfUserSort).fit()
#       2 print(results.summary())
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, *args, **kwargs)
#      96         if subset is not None:
#      97             data= data.ix[subset]
# ---> 98         endog, exog = handle_formula_data(data, None, formula)
#      99         mod = cls(endog, exog, *args, **kwargs)
#     100         mod.formula = formula
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/statsmodels/formula/formulatools.pyc in handle_formula_data(Y, X, formula, depth)
#      43     else:
#      44         if data_util._is_using_pandas(Y, None):
# ---> 45             return dmatrices(formula, Y, 2, return_type='dataframe')
#      46         else:
#      47             return dmatrices(formula, Y, 2, return_type='dataframe')
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     297                                       NA_action, return_type)
#     298     if lhs.shape[1] == 0:
# --> 299         raise PatsyError("model is missing required outcome variables")
#     300     return (lhs, rhs)
#
# PatsyError: model is missing required outcome variables

# %% [markdown]
# The above shows that linear regression does not explain the relationship overly well, as we only get an R-squared of 0.11

# %%
fig1, ax1 = plt.subplots(figsize=(17,5))
sns.distplot(dfUserSort['BalancePrePour'], color="seagreen");

# %%
results = ols('PricePerVolume ~ Volume', dfUserSort).fit()
print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-105-4700fd355251> in <module>()
# ----> 1 results = ols('PricePerVolume ~ Volume', dfUserSort).fit()
#       2 print(results.summary())
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, *args, **kwargs)
#      96         if subset is not None:
#      97             data= data.ix[subset]
# ---> 98         endog, exog = handle_formula_data(data, None, formula)
#      99         mod = cls(endog, exog, *args, **kwargs)
#     100         mod.formula = formula
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/statsmodels/formula/formulatools.pyc in handle_formula_data(Y, X, formula, depth)
#      43     else:
#      44         if data_util._is_using_pandas(Y, None):
# ---> 45             return dmatrices(formula, Y, 2, return_type='dataframe')
#      46         else:
#      47             return dmatrices(formula, Y, 2, return_type='dataframe')
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     297                                       NA_action, return_type)
#     298     if lhs.shape[1] == 0:
# --> 299         raise PatsyError("model is missing required outcome variables")
#     300     return (lhs, rhs)
#
# PatsyError: model is missing required outcome variables

# %% [markdown]
# ## Adding in external data

# %% [markdown]
# ### Understanding the context of each machine

# %% [markdown]
# #### Business Group

# %% [markdown]
# Firstly we can look at the business groups that own the machines:

# %%
dfUserSort.OriginGroup.unique()
# Out:
# array(['DNC', 'philips.arena', 'ab.naz', 'ab.onpremise'], dtype=object)

# %% [markdown]
# #### Location of machines

# %% [markdown]
# Next we can look at where each machine unit is placed by these groups:

# %%
dfPhilips = dfUserSort.loc[dfUserSort['OriginGroup'] == "philips.arena"]
dfPhilips.OriginUnit.unique()
# Out:
# array(['philips03.r', 'philips01.l', 'philips02.r', 'philips03.l',
#        'philips02.l', 'philips01.r'], dtype=object)

# %%
dfDNC = dfUserSort.loc[dfUserSort['OriginGroup'] == "DNC"]
dfDNC.OriginUnit.unique()
# Out:
# array(['Indians01', 'Indians03', 'Indians04', 'Indians02', 'Indians05',
#        'Indians06'], dtype=object)

# %%
dfabonpremise = dfUserSort.loc[dfUserSort['OriginGroup'] == "ab.onpremise"]
dfabonpremise.OriginUnit.unique()
# Out:
# array(['reds01.l', 'reds09.l', 'reds09.r', 'reds07.l', 'reds16.r',
#        'reds01.r', 'reds07.r', 'reds17.l', 'reds13.l', 'reds02.r',
#        'reds17.r', 'reds03.r', 'reds05.l', 'reds04.r', 'reds18.r',
#        'reds15.r', 'reds14.l', 'reds12.r', 'reds15.l', 'reds12.l',
#        'reds03.l', 'reds05.r', 'reds13.r', 'reds10.l', 'reds06.l',
#        'reds19.r', 'reds06.r', 'reds11.r', 'reds02.l', 'reds16.l',
#        'reds20.r', 'reds20.l', 'reds18.l', 'reds11.l', 'reds04.l',
#        'reds19.l', 'reds14.r', 'reds10.r', 'reds08.r', 'reds08.l',
#        'twins01.r', 'twins03.l', 'twins02.l', 'twins02.r', 'twins01.l',
#        'twins03.r'], dtype=object)

# %% [markdown]
# From the above we can see that:
#
# * Philips and DNC has one location
# * AB has two locations

# %% [markdown]
# #### Dates machines are used

# %%
print dfPhilips.Date.unique()
# Out:
# ['13/04/15' '19/04/15' '07/04/15' '22/04/15' '10/04/15' '11/04/15']

# %%
dfIndians01 = dfUserSort.loc[dfUserSort['OriginUnit'] == "Indians01"]
print dfIndians01.Date.unique()
# Out:
# ['10/04/15' '06/04/15' '11/04/15' '15/04/15' '12/04/15' '14/04/15']

# %%
dfreds01 = dfUserSort.loc[dfUserSort['OriginUnit'] == "reds01.l"]
print dfreds01.Date.unique()
# Out:
# ['06/04/15' '12/04/15' '25/04/15' '11/04/15' '10/04/15' '24/04/15'
#  '08/04/15' '09/04/15']

# %%
dftwins01 = dfUserSort.loc[dfUserSort['OriginUnit'] == "twins01.r"]
print dftwins01.Date.unique()
# Out:
# ['18/04/15' '17/04/15' '19/04/15' '13/04/15' '15/04/15' '16/04/15']

# %% [markdown]
# ### Game results for each stadium on each day

# %% [markdown]
# A bit of research tells us that at each stadium the following results were recorded in April:
#
# * Hawks:
#     * Win - 7th
#     * Win - 10th
#     * Loss - 13th
#     * Win - 19th
#     * Win - 22nd
#     * 11th was a comedy show
#
# * Cincinnati Reds:
#     * Win - 6th
#     * Win - 8th
#     * Win - 9th
#     * Win - 10th
#     * Loss - 11th
#     * Loss - 12th
#     * 13th - Playing away, but machines still in use
#     * 15th - Playing away, but machines still in use
#     * 16th - Playing away, but machines still in use
#     * 17th - Playing away, but machines still in use
#     * 18th - Playing away, but machines still in use
#     * 19th - Playing away, but machines still in use
#     * Loss - 24th
#     * Rain stops play - 25th
#
# * Twins:
#     * Loss - 13th
#     * Win - 15th
#     * Win - 16th
#     * Win - 17th
#     * Loss - 18th
#     * Win - 19th
#
# * Indians:
#     * 6th - Playing away
#     * Loss - 10th
#     * Loss - 11th
#     * Loss - 12th
#     * Loss - 14th
#     * Win - 15th

# %% [markdown]
# ### Map game results to machines

# %%
dfUserSort['Team'] = "NA"

for x, row in dfUserSort.iterrows():
    if dfUserSort["OriginGroup"].ix[x] == "DNC":
        dfUserSort["Team"].ix[x] = "Indians"
    elif dfUserSort["OriginGroup"].ix[x] == "philips.arena":
        dfUserSort["Team"].ix[x] = "Hawks"
    elif dfUserSort["OriginGroup"].ix[x] == "ab.onpremise":
        if dfUserSort["OriginUnit"].ix[x] == 'twins01.r' or dfUserSort["OriginUnit"].ix[x] == 'twins03.l' or \
        dfUserSort["OriginUnit"].ix[x] == 'twins02.l' or dfUserSort["OriginUnit"].ix[x] == 'twins02.r' or \
        dfUserSort["OriginUnit"].ix[x] == 'twins01.l' or dfUserSort["OriginUnit"].ix[x] == 'twins03.r':
            dfUserSort["Team"].ix[x] = "Twins"
        else:
            dfUserSort["Team"].ix[x] = "Reds"

# %%
print len(dfUserSort.loc[dfUserSort['Team'] == 'Reds'])
print len(dfUserSort.loc[dfUserSort['Team'] == 'Indians'])
print len(dfUserSort.loc[dfUserSort['Team'] == 'Hawks'])
print len(dfUserSort.loc[dfUserSort['Team'] == 'Twins'])
# Out:
# 14748
# 2878
# 1418
# 2119

# %%
def setwins(df):
    df['Result'] = "NA"
    for x, row in df.iterrows():
        if df["Team"].ix[x] == "Indians":
            if df["Date"].ix[x] == "15/04/15":
                df['Result'].ix[x] = "Win"
            elif df["Date"].ix[x] == "06/04/15":
                df['Result'].ix[x] = "NA"
            else:
                df['Result'].ix[x] = "Loss"
        if df["Team"].ix[x] == "Twins":
            if df["Date"].ix[x] == "13/04/15" or df["Date"].ix[x] == "18/04/15":
                df['Result'].ix[x] = "Loss"
            else:
                df['Result'].ix[x] = "Win"
        if df["Team"].ix[x] == "Reds":
            if df["Date"].ix[x] == "11/04/15" or df["Date"].ix[x] == "12/04/15" or df["Date"].ix[x] == "24/04/15":
                df['Result'].ix[x] = "Loss"
            elif df["Date"].ix[x] == "06/04/15" or df["Date"].ix[x] == "08/04/15" or \
                df["Date"].ix[x] == "09/04/15" or df["Date"].ix[x] == "10/04/15":
                df['Result'].ix[x] = "Win"
            else:
                df['Result'].ix[x] = "NA"
        if df["Team"].ix[x] == "Hawks":
            if df["Date"].ix[x] == "13/04/15":
                df['Result'].ix[x] = "Loss"
            elif df["Date"].ix[x] == "11/04/15":
                df['Result'].ix[x] = "NA"
            else:
                df['Result'].ix[x] = "Win"

setwins(dfUserSort)

# %%
dfgames = dfUserSort.loc[dfUserSort['Result'] != "NA"]
dfGamesGrouped = dfgames.groupby(['Date', 'Team']).sum()
dfGamesGrouped = dfGamesGrouped.reset_index().sort(['Team', 'Volume'], ascending=[1, 0])
setwins(dfGamesGrouped)
dfGamesGrouped['TeamDate'] = "NA"
for x in range(0, len(dfGamesGrouped)):
    dfGamesGrouped['TeamDate'].ix[x] = dfGamesGrouped.Team.ix[x][:1] + "-" + dfGamesGrouped.Date.ix[x][:2]

# %%
table(dfGamesGrouped)
# Out:
# <table class="table table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Team</th>
#       <th>TapNumber</th>
#       <th>Brand</th>
#       <th>Volume</th>
#       <th>Charge</th>
#       <th>PricePerVolume</th>
#       <th>VolumeRemain</th>
#       <th>PrePaidRemain</th>
#       <th>CardNumber</th>
#       <th>BalancePrePour</th>
#       <th>log_BalancePrePour</th>
#       <th>log_Volume</th>
#       <th>Result</th>
#       <th>TeamDate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td> 22/04/15</td>
#       <td>   Hawks</td>
#       <td>  462</td>
#       <td>  4629</td>
#       <td>  5017.63</td>
#       <td>  2045.16</td>
#       <td>  149.73</td>
#       <td>  5276.10</td>
#       <td>  2110.10</td>
#       <td>  15873235</td>
#       <td>  4155.26</td>
#       <td>  805.187284</td>
#       <td>   896.265602</td>
#       <td>  Win</td>
#       <td> H-22</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td> 19/04/15</td>
#       <td>   Hawks</td>
#       <td>  480</td>
#       <td>  4904</td>
#       <td>  4961.75</td>
#       <td>  2024.71</td>
#       <td>  150.53</td>
#       <td>  5725.20</td>
#       <td>  1879.59</td>
#       <td>  16713347</td>
#       <td>  3904.30</td>
#       <td>  797.958435</td>
#       <td>   902.745491</td>
#       <td>  Win</td>
#       <td> H-19</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td> 10/04/15</td>
#       <td>   Hawks</td>
#       <td>  351</td>
#       <td>  3307</td>
#       <td>  3225.36</td>
#       <td>  1299.28</td>
#       <td>   99.81</td>
#       <td>  3577.35</td>
#       <td>  1174.07</td>
#       <td>  11749691</td>
#       <td>  2473.35</td>
#       <td>  515.988299</td>
#       <td>   594.668519</td>
#       <td>  Win</td>
#       <td> H-10</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td> 07/04/15</td>
#       <td>   Hawks</td>
#       <td>  289</td>
#       <td>  2830</td>
#       <td>  2764.41</td>
#       <td>  1109.04</td>
#       <td>   85.15</td>
#       <td>  3288.51</td>
#       <td>  1143.74</td>
#       <td>   3268180</td>
#       <td>  2252.78</td>
#       <td>  469.314270</td>
#       <td>   512.806189</td>
#       <td>  Win</td>
#       <td> H-07</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td> 13/04/15</td>
#       <td>   Hawks</td>
#       <td>  231</td>
#       <td>  1807</td>
#       <td>  2096.83</td>
#       <td>   827.41</td>
#       <td>   65.78</td>
#       <td>  2504.39</td>
#       <td>   775.97</td>
#       <td>   7603912</td>
#       <td>  1603.38</td>
#       <td>  338.764119</td>
#       <td>   393.671526</td>
#       <td> Loss</td>
#       <td> H-13</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td> 10/04/15</td>
#       <td> Indians</td>
#       <td> 1216</td>
#       <td>  9473</td>
#       <td> 10152.49</td>
#       <td>  5685.24</td>
#       <td>  474.88</td>
#       <td> 36392.18</td>
#       <td> 10103.45</td>
#       <td>  47626108</td>
#       <td> 15788.69</td>
#       <td> 2190.402572</td>
#       <td>  1987.786224</td>
#       <td> Loss</td>
#       <td> I-10</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td> 11/04/15</td>
#       <td> Indians</td>
#       <td> 1265</td>
#       <td>  9549</td>
#       <td>  9956.82</td>
#       <td>  5575.64</td>
#       <td>  469.84</td>
#       <td> 35597.94</td>
#       <td>  9774.70</td>
#       <td>  51932581</td>
#       <td> 15350.34</td>
#       <td> 2181.302899</td>
#       <td>  1957.067772</td>
#       <td> Loss</td>
#       <td> I-11</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td> 12/04/15</td>
#       <td> Indians</td>
#       <td>  898</td>
#       <td>  7134</td>
#       <td>  6822.10</td>
#       <td>  3820.37</td>
#       <td>  315.28</td>
#       <td> 24921.66</td>
#       <td>  6269.29</td>
#       <td>  34967273</td>
#       <td> 10089.66</td>
#       <td> 1444.148847</td>
#       <td>  1335.250940</td>
#       <td> Loss</td>
#       <td> I-12</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td> 14/04/15</td>
#       <td> Indians</td>
#       <td>  451</td>
#       <td>  3409</td>
#       <td>  3141.46</td>
#       <td>  1759.09</td>
#       <td>  155.68</td>
#       <td> 12598.92</td>
#       <td>  2477.28</td>
#       <td>  17425371</td>
#       <td>  4236.37</td>
#       <td>  685.097553</td>
#       <td>   640.206457</td>
#       <td> Loss</td>
#       <td> I-14</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td> 15/04/15</td>
#       <td> Indians</td>
#       <td>  389</td>
#       <td>  2987</td>
#       <td>  2771.36</td>
#       <td>  1552.02</td>
#       <td>  137.20</td>
#       <td> 10888.18</td>
#       <td>  2915.07</td>
#       <td>  15014471</td>
#       <td>  4467.09</td>
#       <td>  640.932158</td>
#       <td>   558.540550</td>
#       <td>  Win</td>
#       <td> I-15</td>
#     </tr>
#     <tr>
#       <th>0 </th>
#       <td> 06/04/15</td>
#       <td>    Reds</td>
#       <td> 5048</td>
#       <td> 24016</td>
#       <td> 65098.17</td>
#       <td> 25846.09</td>
#       <td> 1457.49</td>
#       <td> 91074.81</td>
#       <td> 25261.00</td>
#       <td> 182048261</td>
#       <td> 51107.09</td>
#       <td> 8945.393983</td>
#       <td> 10103.262811</td>
#       <td>  Win</td>
#       <td> R-06</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td> 24/04/15</td>
#       <td>    Reds</td>
#       <td> 3303</td>
#       <td> 15229</td>
#       <td> 38648.79</td>
#       <td> 15258.67</td>
#       <td>  923.82</td>
#       <td> 60686.44</td>
#       <td> 17757.77</td>
#       <td> 124611772</td>
#       <td> 33016.44</td>
#       <td> 5537.133389</td>
#       <td>  6242.875288</td>
#       <td> Loss</td>
#       <td> R-24</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td> 11/04/15</td>
#       <td>    Reds</td>
#       <td> 2920</td>
#       <td> 13750</td>
#       <td> 35146.51</td>
#       <td> 13846.71</td>
#       <td>  844.14</td>
#       <td> 56301.59</td>
#       <td> 15564.95</td>
#       <td> 111589085</td>
#       <td> 29411.66</td>
#       <td> 5092.767988</td>
#       <td>  5705.140050</td>
#       <td> Loss</td>
#       <td> R-11</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td> 12/04/15</td>
#       <td>    Reds</td>
#       <td> 3017</td>
#       <td> 14063</td>
#       <td> 34824.32</td>
#       <td> 13750.44</td>
#       <td>  857.52</td>
#       <td> 58445.23</td>
#       <td> 16321.36</td>
#       <td> 115006551</td>
#       <td> 30071.80</td>
#       <td> 5138.693784</td>
#       <td>  5723.767084</td>
#       <td> Loss</td>
#       <td> R-12</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td> 08/04/15</td>
#       <td>    Reds</td>
#       <td> 2085</td>
#       <td> 10353</td>
#       <td> 26167.35</td>
#       <td> 10313.68</td>
#       <td>  631.56</td>
#       <td> 43629.24</td>
#       <td> 10612.76</td>
#       <td>  81474598</td>
#       <td> 20926.44</td>
#       <td> 3782.920182</td>
#       <td>  4280.021692</td>
#       <td>  Win</td>
#       <td> R-08</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td> 10/04/15</td>
#       <td>    Reds</td>
#       <td> 1767</td>
#       <td>  8420</td>
#       <td> 22050.63</td>
#       <td>  8659.46</td>
#       <td>  517.62</td>
#       <td> 34739.38</td>
#       <td>  9863.80</td>
#       <td>  67895529</td>
#       <td> 18523.26</td>
#       <td> 3152.649442</td>
#       <td>  3544.050990</td>
#       <td>  Win</td>
#       <td> R-10</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td> 09/04/15</td>
#       <td>    Reds</td>
#       <td>  674</td>
#       <td>  3106</td>
#       <td>  7401.32</td>
#       <td>  2946.11</td>
#       <td>  185.55</td>
#       <td> 12695.46</td>
#       <td>  2964.74</td>
#       <td>  23856821</td>
#       <td>  5910.85</td>
#       <td> 1079.873682</td>
#       <td>  1232.736053</td>
#       <td>  Win</td>
#       <td> R-09</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td> 13/04/15</td>
#       <td>   Twins</td>
#       <td> 1065</td>
#       <td> 11342</td>
#       <td> 10682.86</td>
#       <td>  4387.69</td>
#       <td>  305.32</td>
#       <td>  9776.77</td>
#       <td>  3385.45</td>
#       <td>  44433938</td>
#       <td>  7773.14</td>
#       <td> 1606.175164</td>
#       <td>  1885.919879</td>
#       <td> Loss</td>
#       <td> T-13</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td> 17/04/15</td>
#       <td>   Twins</td>
#       <td>  613</td>
#       <td>  6200</td>
#       <td>  5460.95</td>
#       <td>  2230.66</td>
#       <td>  166.26</td>
#       <td>  5802.23</td>
#       <t

# %%
fig1, ax1 = plt.subplots(figsize=(17,5))
sns.barplot(dfGamesGrouped.TeamDate, y=dfGamesGrouped['Volume'], hue=dfGamesGrouped.Result);

# %% [markdown]
# We can see that there are large variations in total beer consumption between different dates, but these differences do not seem to be due to wins or losses.  A much better estimate might be game attendance.

# %% [markdown]
# ### Game attendance

# %% [markdown]
# Each stadium reported the following attendance figures for April:
#
# * Hawks:
#     * 7th - 18,650
#     * 10th - 18,462
#     * 13th - 18,265
#     * 19th - 18,440
#     * 22nd - 18,207
#     * 11th was a comedy show
#
# * Cincinnati Reds:
#     * 6th - 43,633
#     * 8th - 30,859
#     * 9th - 15,616
#     * 10th - 30,808
#     * 11th - 41,525
#     * 12th - 41,446
#     * 13th - Playing away, but machines still in use
#     * 15th - Playing away, but machines still in use
#     * 16th - Playing away, but machines still in use
#     * 17th - Playing away, but machines still in use
#     * 18th - Playing away, but machines still in use
#     * 19th - Playing away, but machines still in use
#     * 24th - 39,891
#     * Rain stops play - 25th - 38,954
#
# * Twins:
#     * 13th - 40,123
#     * 15th - 21,362
#     * 16th - 17,449
#     * 17th - 21,307
#     * 18th - 23,949
#     * 19th - 17,923
#
# * Indians:
#     * 6th - Playing away
#     * 10th - 35,789
#     * 11th - 23,161
#     * 12th - 19,555
#     * 14th - 10,642
#     * 15th - 11,042

# %% [markdown]
# ### Map attendance to machines

# %%
def setAttendance(df):
    df['Attendance'] = 0
    for x, row in df.iterrows():
        if df["Team"].ix[x] == "Indians":
            if df["Date"].ix[x] == "10/04/15":
                df['Attendance'].ix[x] = 35789
            elif df["Date"].ix[x] == "11/04/15":
                df['Attendance'].ix[x] = 23161
            elif df["Date"].ix[x] == "12/04/15":
                df['Attendance'].ix[x] = 19555
            elif df["Date"].ix[x] == "14/04/15":
                df['Attendance'].ix[x] = 10642
            elif df["Date"].ix[x] == "15/04/15":
                df['Attendance'].ix[x] = 11042         
        if df["Team"].ix[x] == "Twins":
            if df["Date"].ix[x] == "13/04/15":
                df['Attendance'].ix[x] = 40123
            elif df["Date"].ix[x] == "15/04/15":
                df['Attendance'].ix[x] = 21362
            elif df["Date"].ix[x] == "16/04/15":
                df['Attendance'].ix[x] = 17449
            elif df["Date"].ix[x] == "17/04/15":
                df['Attendance'].ix[x] = 21307
            elif df["Date"].ix[x] == "18/04/15":
                df['Attendance'].ix[x] = 23949
            else:
                df['Attendance'].ix[x] = 17923 
        if df["Team"].ix[x] == "Reds":
            if df["Date"].ix[x] == "06/04/15":
                df['Attendance'].ix[x] = 43633
            elif df["Date"].ix[x] == "08/04/15":
                df['Attendance'].ix[x] = 30859
            elif df["Date"].ix[x] == "09/04/15":
                df['Attendance'].ix[x] = 15616
            elif df["Date"].ix[x] == "10/04/15":
                df['Attendance'].ix[x] = 30808
            elif df["Date"].ix[x] == "11/04/15":
                df['Attendance'].ix[x] = 41525
            elif df["Date"].ix[x] == "12/04/15":
                df['Attendance'].ix[x] = 41446
            elif df["Date"].ix[x] == "24/04/15":
                df['Attendance'].ix[x] = 39891
        if df["Team"].ix[x] == "Hawks":
            if df["Date"].ix[x] == "07/04/15":
                df['Attendance'].ix[x] = 18650
            elif df["Date"].ix[x] == "10/04/15":
                df['Attendance'].ix[x] = 18462
            elif df["Date"].ix[x] == "13/04/15":
                df['Attendance'].ix[x] = 18265
            elif df["Date"].ix[x] == "19/04/15":
                df['Attendance'].ix[x] = 18440
            elif df["Date"].ix[x] == "22/04/15":
                df['Attendance'].ix[x] = 18207

setAttendance(dfUserSort)

# %%
setAttendance(dfGamesGrouped)

# %%
fig1, ax1 = plt.subplots(figsize=(17,5))
sns.barplot(dfGamesGrouped.TeamDate, y=dfGamesGrouped['Attendance'], hue=dfGamesGrouped.Result)

# %%
sns.lmplot('Attendance', 'Volume', dfGamesGrouped, size=9, aspect=2);

# %%
results = ols('Attendance ~ Volume', dfGamesGrouped).fit()
print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-138-6397763fd176> in <module>()
# ----> 1 results = ols('Attendance ~ Volume', dfGamesGrouped).fit()
#       2 print(results.summary())
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, *args, **kwargs)
#      96         if subset is not None:
#      97             data= data.ix[subset]
# ---> 98         endog, exog = handle_formula_data(data, None, formula)
#      99         mod = cls(endog, exog, *args, **kwargs)
#     100         mod.formula = formula
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/statsmodels/formula/formulatools.pyc in handle_formula_data(Y, X, formula, depth)
#      43     else:
#      44         if data_util._is_using_pandas(Y, None):
# ---> 45             return dmatrices(formula, Y, 2, return_type='dataframe')
#      46         else:
#      47             return dmatrices(formula, Y, 2, return_type='dataframe')
#
# /Users/agoosester/anaconda/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     297                                       NA_action, return_type)
#     298     if lhs.shape[1] == 0:
# --> 299         raise PatsyError("model is missing required outcome variables")
#     300     return (lhs, rhs)
#
# PatsyError: model is missing required outcome variables

# %% [markdown]
# #### Given the attendence, does winning or losing affect beer consumption volume?

# %% [markdown]
# TO DO

# %% [markdown]
# ## Impact of trying a small amount of beer on a users' subsequent pour

# %% [markdown]
# Firstly, let's have a look at the volume distribution of some different brands

# %%
dfUserSort.hist('Volume', by=dfUserSort.Product, color='dodgerblue', figsize=(20, 20));

# %% [markdown]
# ### Determining whether a user is tasting, pouring a pint or finishing their card balance

# %%
dfUserSort['Taster'] = 0
dfUserSort['FullDrink'] = 0
dfUserSort['Finisher'] = 0

for x, row in dfUserSort.iterrows():
    if dfUserSort["BalancePrePour"].ix[x] > 6:
        if dfUserSort["Volume"].ix[x] < 10:
            dfUserSort['Taster'].ix[x] = 1
        else:
            dfUserSort['FullDrink'].ix[x] = 1
    else:
        dfUserSort['Finisher'].ix[x] = 1

# %%
pourTypes = [dfUserSort.Taster.describe()['mean'], dfUserSort.FullDrink.describe()['mean'], dfUserSort.Finisher.describe()['mean']] 
dfPourType = pd.DataFrame(data = pourTypes)
dfPourType = dfPourType.rename(index={0: 'Taster', 1: 'FullDrink', 2:'BalanceFinisher'})
dfPourType.columns = ['PourType']
dfPourType.plot(kind='bar', figsize=(15,7), color='orange');

# %%
groupedBrand = dfUserSort.groupby('Brand').mean()
groupedBrand = groupedBrand.reset_index()

# %%
fig1, ax1 = plt.subplots(figsize=(15,7))
sns.barplot('Brand', 'Taster', data=groupedBrand);

# %% [markdown]
# ### Create a model!

# %% [markdown]
# Still to do:
#
# * Create a model that predicts a user's action after tasting a beer of a certain brand.  Is the user likely to pour a full pint of that brand, taste another or pour a pint of another
# * Clean up structure of notebook
